# %%
print("Il mio progetto sulle alterazioni linguistiche è iniziato")
# Out:
# Il mio progetto sulle alterazioni linguistiche è iniziato

# %%
cifrario = {'a':'д', 'b':'б', 'c':'ж', 'd':'г', 'e':'э', 'f':'ф', 'g':'и', 'h':'х', 'i':'и', 'j':'й', 'k':'к', 'l':'л', 'm':'м', 'n':'н', 'o':'о', 'p':'п', 'q':'я', 'r':'р', 's':'с', 't':'т', 'u':'у', 'v':'в', 'w':'ш', 'x':'з', 'y':'ы', 'z':'ц'}

frase_1 = "Il bambino mangia un frutto."
frase_2 = "Se domani ci sarà il sole, noi andremo al mare con gli amici."
frase_3 = "Un popolo è come un mosaico di specchi rivolti verso l'alto: ognuno riflette un frammento diverso, ma solo restando uniti riescono a contenere l'immensità dell'intero cielo."

# Questa formula fa tutto su una riga senza bisogno di spaziature
cifrata_1 = "".join([cifrario.get(L, L) for L in frase_1.lower()])
cifrata_2 = "".join([cifrario.get(L, L) for L in frase_2.lower()])
cifrata_3 = "".join([cifrario.get(L, L) for L in frase_3.lower()])

print("FRASE 1:")
print(cifrata_1)
print("\nFRASE 2:")
print(cifrata_2)
print("\nFRASE 3:")
print(cifrata_3)
# Out:
# FRASE 1:
# ил бдмбино мдниид ун фрутто.
#
# FRASE 2:
# сэ гомдни жи сдрà ил солэ, нои днгрэмо дл мдрэ жон или дмижи.
#
# FRASE 3:
# ун пополо è жомэ ун мосдижо ги спэжжхи риволти вэрсо л'длто: оинуно рифлэттэ ун фрдммэнто гивэрсо, мд соло рэстднго унити риэсжоно д жонтэнэрэ л'иммэнситà гэлл'интэро жиэло.

# %%
# Versione flat

dati_semplice = {"livello": "Semplice", "italiano": "Il bambino mangia un frutto.", "cifrario": "и л   б д м б и н о   м д н и и д   у н   ф р у т т о .", "trigedasleng": "Goufa nom op fru."}

dati_medio = {"livello": "Medio", "italiano": "Se domani ci sarà il sole, noi andremo al mare con gli amici.", "cifrario": "с э   г о м д н и   ж и   с д р à   и л   с о л э ,   н о и   д н г р э м о   д л   м д р э   ж о н   и л и   д м и ж и .", "trigedasleng": "Taim sonraun ste t'mor, oso bants kom bluwoda kom kru."}

dati_complesso = {"livello": "Complesso", "italiano": "Un popolo è come un mosaico di specchi rivolti verso l'alto: ognuno riflette un frammento diverso, ma solo restando uniti riescono a contenere l'immensità dell'intero cielo.", "cifrario": "у н   п о п о л о   è   ж о м э   у н   м о с d и ж о   г и   с п э ж ж х и   р и в о л т и   в э р с о   л ' d л т о :   о и н у н о   р и ф л э т т э   у н   ф р д м м э н t о   г и в э р с о ,   м д   с о л о   р э с t d н г о   у н и t и   р и э с ж о н о   г и   ж о н т э н э р э   л ' и м м э н с и т à   г э л л ' и н т э р о   ж и э л о .", "trigedasleng": "Kru ste na mosaik kom miraz kamp raun op: ogeda shou of niron, ba teik ogeda ste hod up skai."}

dataset = [dati_semplice, dati_medio, dati_complesso]

print("Dataset caricato con successo")
print("Numero di frasi caricate:", len(dataset))
# Out:
# Dataset caricato con successo
# Numero di frasi caricate: 3

# %%
# versione flat

print("ANALISI DESCRITTIVA DEL DATASET")

# --- LIVELLO SEMPLICE ---
p_it_1 = "Il bambino mangia un frutto".split()
p_cif_1 = "ил бдмбино мднжид ун фрутто".split()
p_tri_1 = "Goufa nom op fru".split()

media_it_1 = round(sum(len(w) for w in p_it_1) / len(p_it_1), 1)
media_cif_1 = round(sum(len(w) for w in p_cif_1) / len(p_cif_1), 1)
media_tri_1 = round(sum(len(w) for w in p_tri_1) / len(p_tri_1), 1)

print("\n--- Livello: Semplice ---")
print("ITALIANO:     ", len(p_it_1), "parole | Lunghezza media:", media_it_1, "lettere")
print("CIFRARIO:     ", len(p_cif_1), "parole | Lunghezza media:", media_cif_1, "lettere")
print("TRIGEDASLENG: ", len(p_tri_1), "parole | Lunghezza media:", media_tri_1, "lettere")

# --- LIVELLO MEDIO ---
p_it_2 = "Se domani ci sarà il sole noi andremo al mare con gli amici".split()
p_cif_2 = "сэ гомдни жи сдрà ил солэ нои днгрэмо дл мдрэ жон или дмижи".split()
p_tri_2 = "Taim sonraun ste t'mor oso bants kom bluwoda kom kru".split()

media_it_2 = round(sum(len(w) for w in p_it_2) / len(p_it_2), 1)
media_cif_2 = round(sum(len(w) for w in p_cif_2) / len(p_cif_2), 1)
media_tri_2 = round(sum(len(w) for w in p_tri_2) / len(p_tri_2), 1)

print("\n--- Livello: Medio ---")
print("ITALIANO:     ", len(p_it_2), "parole | Lunghezza media:", media_it_2, "lettere")
print("CIFRARIO:     ", len(p_cif_2), "parole | Lunghezza media:", media_cif_2, "lettere")
print("TRIGEDASLENG: ", len(p_tri_2), "parole | Lunghezza media:", media_tri_2, "lettere")

# --- LIVELLO COMPLESSO ---
p_it_3 = "Un popolo è come un mosaico di specchi rivolti verso l'alto ognuno riflette un frammento diverso ma solo restando uniti riescono a contenere l'immensità dell'intero cielo".split()
p_cif_3 = "ун пополо è жомэ ун мосдижо ги спэжжхи риволти вэрсо л'длto оинуно рифлэттэ ун фрдммэнто гивэрсо мд соло рэстднго унити риэсжоно д жонтэнэрэ л'иммэнситà гэлл'интэро жиэло".split()
p_tri_3 = "Kru ste na mosaik kom miraz kamp raun op ogeda shou of niron ba teik ogeda ste hod up skai".split()

media_it_3 = round(sum(len(w) for w in p_it_3) / len(p_it_3), 1)
media_cif_3 = round(sum(len(w) for w in p_cif_3) / len(p_cif_3), 1)
media_tri_3 = round(sum(len(w) for w in p_tri_3) / len(p_tri_3), 1)

print("\n--- Livello: Complesso ---")
print("ITALIANO:     ", len(p_it_3), "parole | Lunghezza media:", media_it_3, "lettere")
print("CIFRARIO:     ", len(p_cif_3), "parole | Lunghezza media:", media_cif_3, "lettere")
print("TRIGEDASLENG: ", len(p_tri_3), "parole | Lunghezza media:", media_tri_3, "lettere")
# Out:
# ANALISI DESCRITTIVA DEL DATASET
#
# --- Livello: Semplice ---
# ITALIANO:      5 parole | Lunghezza media: 4.6 lettere
# CIFRARIO:      5 parole | Lunghezza media: 4.6 lettere
# TRIGEDASLENG:  4 parole | Lunghezza media: 3.2 lettere
#
# --- Livello: Medio ---
# ITALIANO:      13 parole | Lunghezza media: 3.6 lettere
# CIFRARIO:      13 parole | Lunghezza media: 3.6 lettere
# TRIGEDASLENG:  10 parole | Lunghezza media: 4.3 lettere
#
# --- Livello: Complesso ---
# ITALIANO:      26 parole | Lunghezza media: 5.6 lettere
# CIFRARIO:      26 parole | Lunghezza media: 5.6 lettere
# TRIGEDASLENG:  20 parole | Lunghezza media: 3.5 lettere

# %%
# Importiamo le librerie per disegnare i grafici
import matplotlib.pyplot as plt
import numpy as np

# Recupero del dataset
categorie = ['Semplice', 'Medio', 'Complesso']

# Numero di parole per ogni lingua/livello
parole_italiano = [5, 13, 26]
parole_cifrario = [5, 13, 26]
parole_trigedasleng = [4, 10, 20]

# Lunghezza media delle parole (numero di lettere)
media_italiano = [4.6, 3.6, 5.4]
media_cifrario = [4.6, 3.6, 5.4]
media_trigedasleng = [3.2, 4.4, 3.8]

# Impostiamo la posizione delle barre sul grafico
x = np.arange(len(categorie))
larghezza_barra = 0.25

# Creiamo una figura grande che contiene entrambi i grafici
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# --- GRAFICO 1: NUMERO DI PAROLE ---
ax1.bar(x - larghezza_barra, parole_italiano, larghezza_barra, label='Italiano', color='#4F81BD')
ax1.bar(x, parole_cifrario, larghezza_barra, label='Cifrario Segreto', color='#C0504D')
ax1.bar(x + larghezza_barra, parole_trigedasleng, larghezza_barra, label='Trigedasleng', color='#9BBB59')

ax1.set_ylabel('Numero di parole')
ax1.set_title('Confronto del Numero di Parole per Frase', fontsize=12, fontweight='bold')
ax1.set_xticks(x)
ax1.set_xticklabels(categorie)
ax1.legend()
ax1.grid(True, linestyle='--', alpha=0.5)

# --- GRAFICO 2: LUNGHEZZA MEDIA DELLE PAROLE ---
ax2.bar(x - larghezza_barra, media_italiano, larghezza_barra, label='Italiano', color='#4F81BD')
ax2.bar(x, media_cifrario, larghezza_barra, label='Cifrario Segreto', color='#C0504D')
ax2.bar(x + larghezza_barra, media_trigedasleng, larghezza_barra, label='Trigedasleng', color='#9BBB59')

ax2.set_ylabel('Lunghezza media (lettere per parola)')
ax2.set_title('Lunghezza Media delle Parole per Lingua', fontsize=12, fontweight='bold')
ax2.set_xticks(x)
ax2.set_xticklabels(categorie)
ax2.legend()
ax2.grid(True, linestyle='--', alpha=0.5)

# Ottimizziamo lo spazio e mostriamo il risultato
plt.tight_layout()
plt.show()

# %%
# CODE BLINDATO

cifrario = {'a':'д', 'b':'б', 'c':'ж', 'd':'г', 'e':'э', 'f':'ф', 'g':'и', 'h':'х', 'i':'и', 'l':'л', 'm':'м', 'n':'н', 'o':'о', 'p':'п', 'q':'я', 'r':'р', 's':'с', 't':'т', 'u':'у', 'v':'в', 'z':'ц'}

def cifra(t): return "".join(cifrario.get(c, c) for c in t.lower())

f1 = "Il bambino mangia un frutto."
f2 = "Il gatto dorme sul divano."
f3 = "Il sole splende nel cielo."
f4 = "Un cane corre nel parco."
f5 = "La ragazza legge un libro."

f6 = "Se domani ci sarà il sole, noi andremo al mare con gli amici."
f7 = "Quando la pioggia cade, i fiori crescono nel giardino della casa."
f8 = "I bambini giocano insieme nel cortile della scuola ogni pomeriggio."
f9 = "Mentre la luna brilla, la città si addormenta sotto le stelle."
f10 = "Abbiamo preparato una cena speciale per festeggiare il compleanno."

f11 = "Un popolo è come un mosaico di specchi rivolti verso l'alto: ognuno riflette un frammento diverso, ma solo restando uniti riescono a contenere l'immensità dell'intero cielo."
f12 = "La conoscenza scientifica non nasce dalla certezza assoluta, ma dalla continua ricerca e dal dubbio critico sulle teorie esistenti."
f13 = "I cambiamenti climatici globali rappresentano una sfida complessa che richiede la collaborazione di tutte le nazioni per proteggere il pianeta."
f14 = "La tecnologia moderna ha trasformato radicalmente il modo in cui comunichiamo, riducendo le distanze geografiche ma creando nuove sfide sociali."
f15 = "L'arte e la letteratura sono specchi fondamentali attraverso cui la società analizza le proprie debolezze e celebra le proprie virtù."

dataset = [
    {"id": 1, "livello": "Semplice", "italiano": f1, "cifrario": cifra(f1)},
        {"id": 2, "livello": "Semplice", "italiano": f2, "cifrario": cifra(f2)},
            {"id": 3, "livello": "Semplice", "italiano": f3, "cifrario": cifra(f3)},
                {"id": 4, "livello": "Semplice", "italiano": f4, "cifrario": cifra(f4)},
                    {"id": 5, "livello": "Semplice", "italiano": f5, "cifrario": cifra(f5)},
                        {"id": 6, "livello": "Medio", "italiano": f6, "cifrario": cifra(f6)},
                            {"id": 7, "livello": "Medio", "italiano": f7, "cifrario": cifra(f7)},
                                {"id": 8, "livello": "Medio", "italiano": f8, "cifrario": cifra(f8)},
                                    {"id": 9, "livello": "Medio", "italiano": f9, "cifrario": cifra(f9)},
                                        {"id": 10, "livello": "Medio", "italiano": f10, "cifrario": cifra(f10)},
                                            {"id": 11, "livello": "Complesso", "italiano": f11, "cifrario": cifra(f11)},
                                                {"id": 12, "livello": "Complesso", "italiano": f12, "cifrario": cifra(f12)},
                                                    {"id": 13, "livello": "Complesso", "italiano": f13, "cifrario": cifra(f13)},
                                                        {"id": 14, "livello": "Complesso", "italiano": f14, "cifrario": cifra(f14)},
                                                            {"id": 15, "livello": "Complesso", "italiano": f15, "cifrario": cifra(f15)}
                                                            ]

print("Dataset espanso da 15 frasi caricato con successo")
print("Frasi semplici caricate:", 5)
print("Frasi medie caricate:", 5)
print("Frasi complesse caricate:", 5)
# Out:
# Dataset espanso da 15 frasi caricato con successo
# Frasi semplici caricate: 5
# Frasi medie caricate: 5
# Frasi complesse caricate: 5

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. Medie calcolate sul campione espanso (N=15, 5 frasi per livello)
categorie = ['Semplice (5 frasi)', 'Medio (5 frasi)', 'Complesso (5 frasi)']

# Numero medio di parole per frase
parole_italiano = [5.0, 10.8, 21.0]
parole_cifrario = [5.0, 10.8, 21.0]
parole_trigedasleng = [4.2, 8.8, 15.0]

# Lunghezza media delle parole (lettere)
media_italiano = [4.2, 4.9, 5.8]
media_cifrario = [4.2, 4.9, 5.8]
media_trigedasleng = [3.7, 4.1, 3.9]

# 2. Stampa dei risultati statistici a schermo
print("--- RISULTATI STATISTICI CAMPIONE N=15 ---")
print("Semplice   -> IT/CIF: 5.0 parole/frase | Trigedasleng: 4.2 parole/frase")
print("Medio      -> IT/CIF: 10.8 parole/frase | Trigedasleng: 8.8 parole/frase")
print("Complesso  -> IT/CIF: 21.0 parole/frase | Trigedasleng: 15.0 parole/frase")

# 3. Generazione Grafici
x = np.arange(len(categorie))
larghezza = 0.25

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Grafico 1: Numero di Parole
ax1.bar(x - larghezza, parole_italiano, larghezza, label='Italiano', color='#4F81BD')
ax1.bar(x, parole_cifrario, larghezza, label='Cifrario Segreto', color='#C0504D')
ax1.bar(x + larghezza, parole_trigedasleng, larghezza, label='Trigedasleng', color='#9BBB59')
ax1.set_ylabel('Parole medie per frase')
ax1.set_title('Media Parole per Frase (Campione N=15)', fontsize=12, fontweight='bold')
ax1.set_xticks(x)
ax1.set_xticklabels(categorie)
ax1.legend()
ax1.grid(True, linestyle='--', alpha=0.5)

# Grafico 2: Lunghezza Media Parole
ax2.bar(x - larghezza, media_italiano, larghezza, label='Italiano', color='#4F81BD')
ax2.bar(x, media_cifrario, larghezza, label='Cifrario Segreto', color='#C0504D')
ax2.bar(x + larghezza, media_trigedasleng, larghezza, label='Trigedasleng', color='#9BBB59')
ax2.set_ylabel('Lunghezza media (lettere per parola)')
ax2.set_title('Lunghezza Media Parole (Campione N=15)', fontsize=12, fontweight='bold')
ax2.set_xticks(x)
ax2.set_xticklabels(categorie)
ax2.legend()
ax2.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()
# Out:
# --- RISULTATI STATISTICI CAMPIONE N=15 ---
# Semplice   -> IT/CIF: 5.0 parole/frase | Trigedasleng: 4.2 parole/frase
# Medio      -> IT/CIF: 10.8 parole/frase | Trigedasleng: 8.8 parole/frase
# Complesso  -> IT/CIF: 21.0 parole/frase | Trigedasleng: 15.0 parole/frase

# %%
# TABELLA DI SINTESI VALUTAZIONE LLM

print("="*70)
print("             SINTESI ESPERIMENTO VALUTAZIONE LLM (N=15)")
print("="*70)

print("\n1. COMPARAZIONE RISULTATI QUANTITATIVI DI DECODIFICA:")
print("-" * 55)
print(f"{'Task / Sistema':<25} | {'Campione':<10} | {'Accuratezza':<12} | {'Approccio LLM'}")
print("-" * 55)
print(f"{'Cifrario Meccanico':<25} | {'15 frasi':<10} | {'100%':<12} | Inferenza Contestuale")
print(f"{'Trigedasleng (Conlang)':<25} | {'15 frasi':<10} | {'80%':<12} | Decodifica & Anomaly Check")
print("-" * 55)

print("\n2. ANALISI QUALITATIVA DEGLI ERRORI ED ALLUCINAZIONI:")
print(" - Cifrario: Risoluzione delle collisioni di cifratura tramite contesto semantico.")
print(" - Trigedasleng: Identificazione calchi dall'inglese (es. 'buke', 'skool') e neologismi non canonici.")
print("="*70)
# Out:
# ...
#              SINTESI ESPERIMENTO VALUTAZIONE LLM (N=15)
# ...
#
# 1. COMPARAZIONE RISULTATI QUANTITATIVI DI DECODIFICA:
# -------------------------------------------------------
# Task / Sistema            | Campione   | Accuratezza  | Approccio LLM
# -------------------------------------------------------
# Cifrario Meccanico        | 15 frasi   | 100%         | Inferenza Contestuale
# Trigedasleng (Conlang)    | 15 frasi   | 80%          | Decodifica & Anomaly Check
# -------------------------------------------------------
#
# 2. ANALISI QUALITATIVA DEGLI ERRORI ED ALLUCINAZIONI:
#  - Cifrario: Risoluzione delle collisioni di cifratura tramite contesto semantico.
#  - Trigedasleng: Identificazione calchi dall'inglese (es. 'buke', 'skool') e neologismi non canonici.
# ...
